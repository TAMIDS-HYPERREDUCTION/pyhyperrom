# %% [markdown]
# ### Load Modules

# %%
# Restart the kernel
import os
import dill as pickle
current_dir ='../../../'
os.chdir(current_dir)

from src.codes.basic import *
from src.codes.utils.fem_utils import *
from src.codes.utils.plot_utils import OneDPlot as plot
from src.codes.utils.plot_utils import data_stats
from src.codes.utils.rom_utils import *

from src.codes.prob_classes.base_class_heat_conduction import FOS_FEM, probdata, ROM_simulation
import src.codes.reductor.rom_class as rom_class
from src.codes.algorithms.ecsw import ecsw_red
from importlib import reload
# reload(deim_module)
import ptitprince as pt
import pandas as pd

# %% [markdown]
# ### Load data

# %%
filename_dataC = 'examples/heat_conduction/OneD_heat_conduction/data/DataClass.dill'
with open(filename_dataC, 'rb') as f:
    Data_cls = pickle.load(f)

# load required variables from data
FOS = Data_cls.FOS
d = FOS.data
param_list = np.asarray(Data_cls.param_list)
NLS = np.asarray(Data_cls.NL_solutions)
K_mus = Data_cls.K_mus
q_mus = Data_cls.q_mus
train_mask, test_mask = Data_cls.train_mask, Data_cls.test_mask 

N_snap,_ = np.shape(NLS)
print(N_snap)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\suparnob\OneDrive - Texas A&M University\Academic\TAMU_MATERIALS\POSTDOC\HYPERREDUCTION\SUPARNO\HYPERREDUCTION__TAMIDS\pyHyperRom\examples\heat_conduction\OneD_heat_conduction\FEM_1D_ecsw.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/suparnob/OneDrive%20-%20Texas%20A%26M%20University/Academic/TAMU_MATERIALS/POSTDOC/HYPERREDUCTION/SUPARNO/HYPERREDUCTION__TAMIDS/pyHyperRom/examples/heat_conduction/OneD_heat_conduction/FEM_1D_ecsw.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> filename_dataC = 'examples/heat_conduction/OneD_heat_conduction/data/DataClass.dill'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/suparnob/OneDrive%20-%20Texas%20A%26M%20University/Academic/TAMU_MATERIALS/POSTDOC/HYPERREDUCTION/SUPARNO/HYPERREDUCTION__TAMIDS/pyHyperRom/examples/heat_conduction/OneD_heat_conduction/FEM_1D_ecsw.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> with open(filename_dataC, 'rb') as f:
#       <a href='vscode-notebook-cell:/c%3A/Users/suparnob/OneDrive%20-%20Texas%20A%26M%20University/Academic/TAMU_MATERIALS/POSTDOC/HYPERREDUCTION/SUPARNO/HYPERREDUCTION__TAMIDS/pyHyperRom/examples/heat_conduction/OneD_heat_conduction/FEM_1D_ecsw.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     Data_cls = pickle.load(f)
#       <a href='vscode-notebook-cell:/c%3A/Users/suparnob/OneDrive%20-%20Texas%20A%26M%20University/Academic/TAMU_MATERIALS/POSTDOC/HYPERREDUCTION/SUPARNO/HYPERREDUCTION__TAMIDS/pyHyperRom/examples/heat_conduction/OneD_heat_conduction/FEM_1D_ecsw.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> # load required variables from data
#
# File c:\Users\suparnob\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'examples/heat_conduction/OneD_heat_conduction/data/DataClass.dill'

# %% [markdown]
# ### Plot data

# %%
fig, ax = plt.subplots(figsize=(5,3.5))

for i in range(N_snap):
    Plot = plot(d.xi[0], NLS[i], ax=ax)
    Plot.line_()
plt.show()

# %% [markdown]
# ## ECSW Hyper-reduction

# %% [markdown]
# ### Train-Test split

# %%
# You may choose to define you train and test set data too!
# train_mask, test_mask = train_test_split(N_snap)

NLS_train = NLS[train_mask][:,d.mask]
param_list_train = param_list[train_mask]

NLS_test = NLS[test_mask][:,d.mask]

# %% [markdown]
# #### Step 1: Perform SVD on the snapshots (calculate $\mathbb{V}(=\mathbb{W}$)):

# %%
plt.rcParams['figure.dpi'] = 100
n_sel, U = svd_mode_selector(NLS_train, tolerance=1e-6,modes=True)
V_sel = U[:, :n_sel]
# Out:
# Number of modes selected: 4

# %%
fig, ax = plt.subplots()

for i in range(n_sel):
    Plot = plot(d.xi[0][d.mask], V_sel[:,i], ax=ax)
    Plot.line_()
    
Plot.ax.set_xlabel('$x$')
Plot.ax.set_ylabel('$\psi(x)$')

plt.show()

# %% [markdown]
# ### Step 2: Perform NNLS for ECSW

# %%
tic_h_setup_b = time.time()

N_snap_train,_ = np.shape(NLS_train)
tol = 1e-2
xi, residual = ecsw_red(d, V_sel, d.Le, K_mus, q_mus, n_sel, N_snap_train, d.mask, NLS_train,tol=tol)

toc_h_setup_b = time.time()
# Out:
# norm of rhs: 7765.239640708012

# %%
plot(np.arange(d.ncells[0]), xi, ax="").element_()
print(f"Fraction of total elements active in the ROM: {len(xi[xi>0])*100/len(xi)}%")
print(f"residual = {residual}")
# Out:
# Fraction of total elements active in the ROM: 11.0%
# residual = 5.133478369623493e-06

# %% [markdown]
# ### ROM Simulation

# %%
eval_rom = True
if eval_rom:
    ROM_h = ROM_simulation(Data_cls, NLS_test, param_list, test_mask, V_sel, xi)#, N_rom_snap=1)
    ROM_h.run_simulation_h_ecsw()
# Out:
# c:\Users\supar\anaconda3\lib\site-packages\scipy\sparse\linalg\_dsolve\linsolve.py:229: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',

# %%
if eval_rom:
    ROM = ROM_simulation(Data_cls, NLS_test, param_list, test_mask, V_sel, xi)#, N_rom_snap=1)
    ROM.run_simulation()

# %% [markdown]
# ### Performance Statistics

# %%
NLS_rom_h = np.asarray(ROM_h.NL_solutions_rom)
ROM_speed_up_h = ROM_h.speed_up_h
ROM_relative_error_h = ROM_h.rom_error

# %%
data_stats(ROM_speed_up_h, show_histogram=True, show_boxplot=True, show_mean_std=True, xlabel="Speed-up", ylabel="Frequency");
data_stats(np.log10(ROM_relative_error_h), show_histogram=True, show_boxplot=True, show_mean_std=True, xlabel="Relative error (log)", ylabel="Frequency");

# %%
NLS_rom = np.asarray(ROM.NL_solutions_rom)
ROM_speed_up = ROM.speed_up
ROM_relative_error = ROM.rom_error

# %%
data_stats(ROM_speed_up, show_histogram=True, show_boxplot=True, show_mean_std=True, xlabel="Speed-up", ylabel="Frequency");
data_stats(np.log10(ROM_relative_error), show_histogram=True, show_boxplot=True, show_mean_std=True, xlabel="Relative error (log)", ylabel="Frequency");

# %%
df_A = pd.DataFrame({'':'With Hyperreduction','Relative error (log)':np.log10(ROM_relative_error_h)})
df_B = pd.DataFrame({'':'Without Hyperreduction','Relative error (log)':np.log10(ROM_relative_error)})

# Combine the DataFrames
df = pd.concat([df_A, df_B])

fig, ax = plt.subplots(figsize=(8, 4))
pt.RainCloud(x = '', y = 'Relative error (log)', data = df, palette = "magma", bw = 0.2,
    width_viol = .7, ax = ax, orient = "h",pointplot = False, dodge=False, alpha=0.65, width_box = 0.25, linewidth=2, point_size =5.0, move=0.2)
plt.show()

# ===

df_C = pd.DataFrame({'':'With Hyperreduction','Speed-up':ROM_speed_up_h})
df_D = pd.DataFrame({'':'Without Hyperreduction','Speed-up':ROM_speed_up})

# Combine the DataFrames
df2 = pd.concat([df_C, df_D])

fig, ax = plt.subplots(figsize=(8.4, 2))
pt.RainCloud(x = '', y = 'Speed-up', data = df_C, palette = "Oranges",
    width_viol = 1.0, ax = ax, orient = "h",pointplot = False, dodge=True, alpha=1.0, width_box = 0.25, linewidth=2, point_size =5.0)

fig, ax = plt.subplots(figsize=(8, 2))
pt.RainCloud(x = '', y = 'Speed-up', data = df_D, palette = "viridis",
    width_viol = 1.0, ax = ax, orient = "h",pointplot = False, dodge=True, alpha=0.95, width_box = 0.25, linewidth=2, point_size =5.0)
plt.show()
