# %% [markdown]
# ### Load Modules

# %%
# Restart the kernel
import os
import dill as pickle
current_dir ='../../../'
os.chdir(current_dir)

from src.codes.basic import *
from src.codes.utils.fem_utils import *
from src.codes.utils.plot_utils import ThreeDPlot as plot
from src.codes.utils.plot_utils import data_stats
from src.codes.utils.rom_utils import *

from src.codes.prob_classes.base_class_heat_conduction import FOS_FEM, probdata, ROM_simulation
import src.codes.reductor.rom_class as rom_class
import src.codes.algorithms.deim as deim_module
from importlib import reload
# reload(deim_module)

# %% [markdown]
# ### Load data

# %%
filename_dataC = 'examples/heat_conduction/ThreeD_heat_conduction/data/DataClass.dill'
with open(filename_dataC, 'rb') as f:
    Data_cls = pickle.load(f)

# load required variables from data
FOS = Data_cls.FOS
d = FOS.data
param_list = np.asarray(Data_cls.param_list)
NLS = np.asarray(Data_cls.NL_solutions)
# train_mask, test_mask = Data_cls.train_mask, Data_cls.test_mask

N_snap,_ = np.shape(NLS)
print(N_snap)
eval_rom = False
# Out:
# 100

# %% [markdown]
# ### Plot data

# %%
for i in range(2):
    Plot = plot(d.xi[0], d.xi[1], d.xi[2], NLS[i])
    Plot.plot3D()
plt.show()

# %% [markdown]
# ## DEIM Hyper-reduction

# %% [markdown]
# ### Train-Test split

# %%
train_mask, test_mask = train_test_split(N_snap)

NLS_train = NLS[train_mask]
param_list_train = param_list[train_mask]

NLS_test = NLS[test_mask]

# %% [markdown]
# #### Step 1: Perform SVD on the snapshots (calculate $\mathbb{V}(=\mathbb{W}$)):

# %%
# plt.rcParams['figure.dpi'] = 100*2
n_sel, U = svd_mode_selector(NLS_train, tolerance=1e-2,modes=True)
V_sel = U[:, :n_sel]
# Out:
# Number of modes selected: 2

# %%
# for i in range(n_sel):
#     plot(d.xi[0], d.xi[1], V_sel[:,i],elev=15, azim=60).surface_()

# %% [markdown]
# ### Step 2: Perform SVD on the force snapshots

# %%
# Force snapshots
F_nl = np.asarray(Data_cls.rhs)
deim = deim_module.deim(d,F_nl,train_mask,param_list,V_sel,NLS_train,d.mask,tol_f=1e-14, extra_modes=0)

tic_h_setup_b = time.time()
deim.select_elems()
toc_h_setup_b = time.time()

xi = deim.xi
# Out:
# Selected modes:2

# %%
plot(0,0,0,0).element3D((d.ncells[0],d.ncells[1],d.ncells[2]), xi, FOS)
print(f"Fraction of total elements active in the ROM: {len(xi[xi>0])*100/len(xi)}%")
# Out:
# Fraction of total elements active in the ROM: 0.9259259259259259%

# %% [markdown]
# ### ROM Simulation

# %%
ROM_h = ROM_simulation(Data_cls, NLS_test, param_list, test_mask, V_sel, xi, deim=deim)#, T_init_guess = 2.0) #N_rom_snap=1,
ROM_h.run_simulation_h_deim();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 ROM_h = ROM_simulation(Data_cls, NLS_test, param_list, test_mask, V_sel, xi, deim=deim)#, T_init_guess = 2.0) #N_rom_snap=1,
# ----> 2 ROM_h.run_simulation_h_deim()
#
# File ~\OneDrive - Texas A&M University\TAMU_MATERIALS\POSTDOC\HYPERREDUCTION\SUPARNO\HYPERREDUCTION__TAMIDS\pyHyperRom\src\codes\prob_classes\base_class_heat_conduction.py:459, in ROM_simulation.run_simulation_h_deim(self)
#     457 tic_rom = time.time()
#     458 ROM_h = rom_class.rom_deim(self.FOS.data, self.deim, self.quad_deg)
# --> 459 NL_solution_p_reduced = ROM_h.solve_rom(T_init_rom,self.xi,self.V_sel)
#     460 toc_rom = time.time()
#     462 rom_sim_time = toc_rom - tic_rom
#
# File ~\OneDrive - Texas A&M University\TAMU_MATERIALS\POSTDOC\HYPERREDUCTION\SUPARNO\HYPERREDUCTION__TAMIDS\pyHyperRom\src\codes\reductor\rom_class.py:280, in rom_deim.solve_rom(self, T_init, xi, V)
#     267 def solve_rom(self, T_init, xi, V):
#     268     """
#     269     Function: solve_rom
#     270     Overview: Solve the nonlinear system for the reduced-order model.
#    (...)
#     278     - Returns the updated temperature field after convergence or reaching max iterations.
#     279     """
# --> 280     T = solve_reduced(self, T_init, xi, V)
#     281     # T = solve_reduced_fsolve(self, T_init, xi, V)
#     283     return T
#
# File ~\OneDrive - Texas A&M University\TAMU_MATERIALS\POSTDOC\HYPERREDUCTION\SUPARNO\HYPERREDUCTION__TAMIDS\pyHyperRom\src\codes\reductor\rom_class.py:84, in solve_reduced(rom_cls, T_init, xi, V, tol, max_iter, op)
#      81 T = np.copy(T_init)
#      83 # Evaluate the reduced Jacobian and residual matrices for the initial guess
# ---> 84 Jac, res = rom_cls.eval_resJac_rom(mask, rom_cls.dir_nodes, rom_cls.sol_dir, T, node_eqnId, xi, V)
#      87 # Compute and display the initial residual norm
#      88 norm_ = np.linalg.norm(res)
#
# File ~\OneDrive - Texas A&M University\TAMU_MATERIALS\POSTDOC\HYPERREDUCTION\SUPARNO\HYPERREDUCTION__TAMIDS\pyHyperRom\src\codes\reductor\rom_class.py:288, in rom_deim.eval_resJac_rom(self, mask, dir_nodes, sol_dir, T_red, node_eqnId, xi, V)
#     286 def eval_resJac_rom(self, mask, dir_nodes, sol_dir, T_red, node_eqnId, xi, V):
# --> 288     K, J, sol_prev, rhs = weighted_matrix_assembly(self, mask, dir_nodes, sol_dir, T_red, node_eqnId, xi, V)
#     290     residual = K @ sol_prev[mask] - rhs.reshape(-1, 1)
#     292     M = self.deim_cls.deim_mat
#
# File ~\OneDrive - Texas A&M University\TAMU_MATERIALS\POSTDOC\HYPERREDUCTION\SUPARNO\HYPERREDUCTION__TAMIDS\pyHyperRom\src\codes\reductor\rom_class.py:33, in weighted_matrix_assembly(rom_cls, mask, dir_nodes, sol_dir, T_red, node_eqnId, xi, V)
#      30 elem_local_node_nonzero_eqnId = rom_cls.data.local_node_nonzero_eqnId[iel]
#      32 # Compute local element matrices and vectors
# ---> 33 Ke_, Je_, qe_ = compute_element_matrices(rom_cls, sol_prev.flatten(), iel)
#      35 # Retrieve global and local indices for stiffness matrices
#      36 I_index, J_index = rom_cls.data.global_indices[iel][0], rom_cls.data.global_indices[iel][1]
#
# File ~\OneDrive - Texas A&M University\TAMU_MATERIALS\POSTDOC\HYPERREDUCTION\SUPARNO\HYPERREDUCTION__TAMIDS\pyHyperRom\src\codes\utils\fem_utils.py:270, in compute_element_matrices(self, sol_prev, iel)
#     252 def compute_element_matrices(self, sol_prev, iel):
#     253     """
#     254     Function: compute_element_matrices
#     255     Overview: This function serves as a wrapper for computing element matrices in the finite element analysis.
#    (...)
#     268     matrices = obj.compute_element_matrices(sol_prev, iel)
#     269     """
# --> 270     return self.element_matrices(sol_prev, iel)
#
# File ~\OneDrive - Texas A&M University\TAMU_MATERIALS\POSTDOC\HYPERREDUCTION\SUPARNO\HYPERREDUCTION__TAMIDS\pyHyperRom\src\codes\prob_classes\base_class_heat_conduction.py:309, in FOS_FEM.element_matrices(self, T_prev, iel)
#     307 # Evaluate temperature and its derivative at quadrature points
#     308 T_prev_q, dT_prev_q = self.eval_at_quadrature_points(T_prev, self.data.gn[iel, :])
# --> 309 cond_q = k(T_prev_q, mu)
#     310 dcond_q = dkdT(T_prev_q, mu)
#     311 qext_q = qext(T_prev_q, mu)
#
# TypeError: 'int' object is not subscriptable

# %%
if eval_rom:
    ROM = ROM_simulation(Data_cls, NLS_test, param_list, test_mask, V_sel, xi)#, N_rom_snap=1)
    ROM.run_simulation()

# %% [markdown]
# ### Performance Statistics

# %%
NLS_rom_h = np.asarray(ROM_h.NL_solutions_rom)
ROM_speed_up_h = ROM_h.speed_up_h
ROM_relative_error_h = ROM_h.rom_error

# %%
data_stats(ROM_speed_up_h, show_histogram=True, show_boxplot=True, show_mean_std=True, xlabel="Speed-up", ylabel="Frequency");
data_stats(np.log10(ROM_relative_error_h), show_histogram=True, show_boxplot=True, show_mean_std=True, xlabel="Relative error (log)", ylabel="Frequency");

# %%
if eval_rom:
    NLS_rom = np.asarray(ROM.NL_solutions_rom)
    ROM_speed_up = ROM.speed_up
    ROM_relative_error = ROM.rom_error

# %%
if eval_rom:
    data_stats(ROM_speed_up, show_histogram=True, show_boxplot=True, show_mean_std=True, xlabel="Speed-up", ylabel="Frequency");
    data_stats(np.log10(ROM_relative_error), show_histogram=True, show_boxplot=True, show_mean_std=True, xlabel="Relative error (log)", ylabel="Frequency");
